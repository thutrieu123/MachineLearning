# %% [markdown]
# <a href="https://colab.research.google.com/github/thutrieu123/MachineLearning/blob/main/GiuaKi_MayHoc_Nhom16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ĐỒ ÁN GIỮA KỲ MÔN MÁY HỌC**
#
# Triệu Anh Thư, Đỗ Minh Phú
#
# PHÂN LOẠI BẦU CỬ QUỐC HỘI HOA KỲ

# %%
# import library
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
import plotly.express as px
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.cluster import KMeans

from sklearn import svm
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_validate, RepeatedStratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# # 1. Giới thiệu

# %% [markdown]
# ## 1.1 Mục tiêu

# %% [markdown]
# ## 1.2 Giới hạn

# %% [markdown]
# *   Dữ liệu (dataset) được lấy từ Kaggle (1854).
# *   Thuật toán máy học được sử dụng để xây dựng các mô hình gồm có: K-Means, kNN, Decition Tree, SVM, Random Forest, Naive Bayes và Neural Network, có thể sử dụng thêm một số thuật toán khác để đối sánh.

# %% [markdown]
# # 2. Chuẩn bị dữ lệu

# %% [markdown]
# ## 2.1 Thu thập dữ liệu

# %% [markdown]
# *   Dữ liệu (dataset) được lấy từ Kaggle (1854).

# %% [markdown]
# ## 2.2 Thăm dò dữ liệu

# %%
# import library from google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/ML/giuaky'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/ML/giuaky

# %%
df = pd.read_csv('house-votes-84.csv');

# %%
df.head(10)
# Out:
#    Class Name  handicapped-infants  water-project-cost-sharing  \
# 0  republican                    n                           y
# 1  republican                    n                           y
# 2    democrat                    ?                           y
# 3    democrat                    n                           y
# 4    democrat                    y                           y
# 5    democrat                    n                           y
# 6    democrat                    n                           y
# 7  republican                    n                           y
# 8  republican                    n                           y
# 9    democrat                    y                           y
#
#    adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                  n                     y                y
# 1                                  n                     y                y
# 2                                  y                     ?                y
# 3                                  y                     n                ?
# 4                                  y                     n                y
# 5                                  y                     n                y
# 6                                  n                     y                y
# 7                                  n                     y                y
# 8                                  n                     y                y
# 9                                  y                     n                n
#
#    religious-groups-in-schools  anti-satellite-test-ban  \
# 0                            y                        n
# 1                            y                        n
# 2                            y                        n
# 3                            y                        n
# 4                            y                        n
# 5                            y                        n
# 6                            y                        n
# 7                            y                        n
# 8                            y                        n
# 9                            n                        y
#
#    aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                          n           n            y
# 1                          n           n            n
# 2                          n           n            n
# 3                          n           n            n
# 4                          n           n            n
# 5                          n           n            n
# 6                          n           n            n
# 7                          n           n            n
# 8                          n           n            n
# 9                          y           y            n
#
#    synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                             ?                   y                       y
# 1                             n                   y                       y
# 2                             y                   n                       y
# 3                             y                   n                       y
# 4                             y                   ?                       y
# 5                             n                   n                       y
# 6                             n                   n                       ?
# 7                             n                   n                       y
# 8                             n                   y                       y
# 9                             n                   n                       n
#
#    crime  duty-free-exports  export-administration-act-south-africa
# 0      y                  n                                       y
# 1      y                  n                                       ?
# 2      y                  n                                       n
# 3      n                  n                                       y
# 4      y                  y                                       y
# 5      y                  y                                       y
# 6      y                  y                                       y
# 7      y                  ?                                       y
# 8      y                  n                                       y
# 9      n                  ?                                       ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Class Name                               435 non-null    object
#  1    handicapped-infants                     435 non-null    object
#  2    water-project-cost-sharing              435 non-null    object
#  3    adoption-of-the-budget-resolution       435 non-null    object
#  4    physician-fee-freeze                    435 non-null    object
#  5    el-salvador-aid                         435 non-null    object
#  6    religious-groups-in-schools             435 non-null    object
#  7    anti-satellite-test-ban                 435 non-null    object
#  8    aid-to-nicaraguan-contras               435 non-null    object
#  9    mx-missile                              435 non-null    object
#  10   immigration                             435 non-null    object
#  11   synfuels-corporation-cutback            435 non-null    object
#  12   education-spending                      435 non-null    object
#  13   superfund-right-to-sue                  435 non-null    object
#  14   crime                                   435 non-null    object
#  15   duty-free-exports                       435 non-null    object
#  16   export-administration-act-south-africa  435 non-null    object
# dtypes: object(17)
# memory usage: 57.9+ KB

# %%
# Đếm mẫu dữ liệu của 1 thuộc tính
df['Class Name'].value_counts()
# Out:
# democrat      267
# republican    168
# Name: Class Name, dtype: int64

# %%
class Info:
    def __init__(self,dataframe):
        self.dataframe = dataframe.drop(['Class Name'],axis=1)
        self.columns = list(self.dataframe.columns)
        self.df = pd.DataFrame()
        self.listY = []
        self.listN = []
        self.listQ = []
        self.main()
        
    def countY(self,x='y'):
        for col in self.columns:
            self.listY.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listY
        
    def countN(self,x='n'):
        for col in self.columns:
            self.listN.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listN
        
    def countQ(self,x='?'):
        for col in self.columns:
            self.listQ.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listQ

    
    def missing_zero_values_table(self):
        mis_val = self.dataframe.isnull().sum()
        mis_val_percent = round(self.dataframe.isnull().mean().mul(100),2)
        mz_table = pd.concat([mis_val,mis_val_percent],axis=1)
        mz_table = mz_table.rename(columns = {self.dataframe.index.name:'col_name',0:'Missing Values',1:'% of Total Values'})
        mz_table['Data_type'] = self.dataframe.dtypes
        print("Your selected dataframe has ** "+str(df.shape[1])+" ** columns and ** "+str(df.shape[0])+" ** Rows.\n"
                 "There are ** "+str(mz_table[mz_table.iloc[:,1] != 0].shape[0])+
                  " ** columns that have missing values. \n")
        self.df = pd.concat([self.df,mz_table],axis=1)
        
    def main(self):
        self.df['col'] = self.columns
        self.countN()
        self.countY()
        self.countQ()
        self.df.set_index('col',inplace=True)
        self.missing_zero_values_table()
        print('Sum No : ',sum(self.listN),
              ', Sum Yes : ',sum(self.listY),
              ', Sum ? : ',sum(self.listQ),
             ', Total : ',sum(self.listN)+sum(self.listY)+sum(self.listQ))

# %%
a = Info(df)
a.df.style.background_gradient(cmap='Reds')
# Out:
# Your selected dataframe has ** 17 ** columns and ** 435 ** Rows.
# There are ** 0 ** columns that have missing values.
#
# Sum No :  3147 , Sum Yes :  3421 , Sum ? :  392 , Total :  6960
# <style type="text/css">
# #T_1870b_row0_col0 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_1870b_row0_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_1870b_row0_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_1870b_row0_col3, #T_1870b_row0_col4, #T_1870b_row1_col3, #T_1870b_row1_col4, #T_1870b_row2_col3, #T_1870b_row2_col4, #T_1870b_row3_col3, #T_1870b_row3_col4, #T_1870b_row4_col3, #T_1870b_row4_col4, #T_1870b_row5_col3, #T_1870b_row5_col4, #T_1870b_row6_col3, #T_1870b_row6_col4, #T_1870b_row7_col3, #T_1870b_row7_col4, #T_1870b_row8_col3, #T_1870b_row8_col4, #T_1870b_row9_col2, #T_1870b_row9_col3, #T_1870b_row9_col4, #T_1870b_row10_col1, #T_1870b_row10_col3, #T_1870b_row10_col4, #T_1870b_row11_col3, #T_1870b_row11_col4, #T_1870b_row12_col3, #T_1870b_row12_col4, #T_1870b_row13_col3, #T_1870b_row13_col4, #T_1870b_row14_col3, #T_1870b_row14_col4, #T_1870b_row15_col0, #T_1870b_row15_col3, #T_1870b_row15_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_1870b_row1_col0 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_1870b_row1_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_1870b_row1_col2 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_1870b_row2_col0, #T_1870b_row9_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_1870b_row2_col1, #T_1870b_row11_col0, #T_1870b_row14_col0 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_1870b_row2_col2, #T_1870b_row3_col2, #T_1870b_row5_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_1870b_row3_col0 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_1870b_row3_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_1870b_row4_col0 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_1870b_row4_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_1870b_row4_col2, #T_1870b_row7_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_1870b_row5_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_1870b_row5_col1, #T_1870b_row10_col0, #T_1870b_row15_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1870b_row6_col0 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_1870b_row6_col1 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_1870b_row6_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_1870b_row7_col0 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_1870b_row7_col1 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_1870b_row8_col0 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_1870b_row8_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_1870b_row8_col2 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_1870b_row9_col0 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_1870b_row10_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_1870b_row11_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_1870b_row11_col2 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_1870b_row12_col0 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_1870b_row12_col1 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_1870b_row12_col2 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_1870b_row13_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_1870b_row13_col1 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_1870b_row13_col2 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_1870b_row14_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_1870b_row14_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_1870b_row15_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1870b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1870b_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_1870b_level0_col1" class="col_heading level0 col1" >y</th>
#       <th id="T_1870b_level0_col2" class="col_heading level0 col2" >?</th>
#       <th id="T_1870b_level0_col3" class="col_heading level0 col3" >Missing Values</th>
#       <th id="T_1870b_level0_col4" class="col_heading level0 col4" >% of Total Values</th>
#       <th id="T_1870b_level0_col5" class="col_heading level0 col5" >Data_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1870b_level0_row0" class="row_heading level0 row0" > handicapped-infants</th>
#       <td id="T_1870b_row0_col0" class="data row0 col0" >236</td>
#       <td id="T_1870b_row0_col1" class="data row0 col1" >187</td>
#       <td id="T_1870b_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_1870b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1870b_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_1870b_row0_col5" class="data row0 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row1" class="row_heading level0 row1" > water-project-cost-sharing</th>
#       <td id="T_1870b_row1_col0" class="data row1 col0" >192</td>
#       <td id="T_1870b_row1_col1" class="data row1 col1" >195</td>
#       <td id="T_1870b_row1_col2" class="data row1 col2" >48</td>
#       <td id="T_1870b_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_1870b_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_1870b_row1_col5" class="data row1 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row2" class="row_heading level0 row2" > adoption-of-the-budget-resolution</th>
#       <td id="T_1870b_row2_col0" class="data row2 col0" >171</td>
#       <td id="T_1870b_row2_col1" class="data row2 col1" >253</td>
#       <td id="T_1870b_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_1870b_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_1870b_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_1870b_row2_col5" class="data row2 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row3" class="row_heading level0 row3" > physician-fee-freeze</th>
#       <td id="T_1870b_row3_col0" class="data row3 col0" >247</td>
#       <td id="T_1870b_row3_col1" class="data row3 col1" >177</td>
#       <td id="T_1870b_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_1870b_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_1870b_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_1870b_row3_col5" class="data row3 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row4" class="row_heading level0 row4" > el-salvador-aid</th>
#       <td id="T_1870b_row4_col0" class="data row4 col0" >208</td>
#       <td id="T_1870b_row4_col1" class="data row4 col1" >212</td>
#       <td id="T_1870b_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_1870b_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_1870b_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_1870b_row4_col5" class="data row4 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row5" class="row_heading level0 row5" > religious-groups-in-schools</th>
#       <td id="T_1870b_row5_col0" class="data row5 col0" >152</td>
#       <td id="T_1870b_row5_col1" class="data row5 col1" >272</td>
#       <td id="T_1870b_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_1870b_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_1870b_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_1870b_row5_col5" class="data row5 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row6" class="row_heading level0 row6" > anti-satellite-test-ban</th>
#       <td id="T_1870b_row6_col0" class="data row6 col0" >182</td>
#       <td id="T_1870b_row6_col1" class="data row6 col1" >239</td>
#       <td id="T_1870b_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_1870b_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_1870b_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_1870b_row6_col5" class="data row6 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_1870b_level0_row7" class="row_heading level0 row7" > aid-to-nicaraguan-contras</th>
#       <td id="T_1870b_row7_col0" class="data row7 col0" >178</td>
#       <td id="

# %%
px.bar(a.df,x=a.df.index, y=['n','y','?'], title="Votes related to laws")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="42ff2606-a56e-4267-919f-17585858fd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42ff2606-a56e-4267-919f-17585858fd2d")) {                    Plotly.newPlot(                        "42ff2606-a56e-4267-919f-17585858fd2d",                        [{"alignmentgroup":"True","hovertemplate":"variable=n<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"n","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"n","offsetgroup":"n","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[236,192,171,247,208,152,182,178,206,212,264,233,201,170,233,62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=y<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"y","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"y","offsetgroup":"y","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[187,195,253,177,212,272,239,242,207,216,150,171,209,248,174,269],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=?<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"?","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"?","offsetgroup":"?","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[12,48,11,11,15,11,14,15,22,7,21,31,25,17,28,104],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %% [markdown]
# ## 2.3 Sơ chế dữ liệu

# %%
# Chuyển đổi dữ liệu
le = LabelEncoder() 
df['Class Name']= le.fit_transform(df['Class Name']) 
df[' handicapped-infants']= le.fit_transform(df[' handicapped-infants']) 
df[' water-project-cost-sharing']= le.fit_transform(df[' water-project-cost-sharing']) 
df[' adoption-of-the-budget-resolution']= le.fit_transform(df[' adoption-of-the-budget-resolution']) 
df[' physician-fee-freeze']= le.fit_transform(df[' physician-fee-freeze']) 
df[' el-salvador-aid']= le.fit_transform(df[' el-salvador-aid']) 
df[' religious-groups-in-schools']= le.fit_transform(df[' religious-groups-in-schools']) 
df[' anti-satellite-test-ban']= le.fit_transform(df[' anti-satellite-test-ban']) 
df[' aid-to-nicaraguan-contras']= le.fit_transform(df[' aid-to-nicaraguan-contras']) 
df[' mx-missile']= le.fit_transform(df[' mx-missile']) 
df[' immigration']= le.fit_transform(df[' immigration']) 
df[' synfuels-corporation-cutback']= le.fit_transform(df[' synfuels-corporation-cutback']) 
df[' education-spending']= le.fit_transform(df[' education-spending']) 
df[' superfund-right-to-sue']= le.fit_transform(df[' superfund-right-to-sue']) 
df[' crime']= le.fit_transform(df[' crime']) 
df[' duty-free-exports']= le.fit_transform(df[' duty-free-exports']) 
df[' export-administration-act-south-africa']= le.fit_transform(df[' export-administration-act-south-africa']) 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Class Name                               435 non-null    int64
#  1    handicapped-infants                     435 non-null    int64
#  2    water-project-cost-sharing              435 non-null    int64
#  3    adoption-of-the-budget-resolution       435 non-null    int64
#  4    physician-fee-freeze                    435 non-null    int64
#  5    el-salvador-aid                         435 non-null    int64
#  6    religious-groups-in-schools             435 non-null    int64
#  7    anti-satellite-test-ban                 435 non-null    int64
#  8    aid-to-nicaraguan-contras               435 non-null    int64
#  9    mx-missile                              435 non-null    int64
#  10   immigration                             435 non-null    int64
#  11   synfuels-corporation-cutback            435 non-null    int64
#  12   education-spending                      435 non-null    int64
#  13   superfund-right-to-sue                  435 non-null    int64
#  14   crime                                   435 non-null    int64
#  15   duty-free-exports                       435 non-null    int64
#  16   export-administration-act-south-africa  435 non-null    int64
# dtypes: int64(17)
# memory usage: 57.9 KB

# %%
df.head(5)
# Out:
#    Class Name   handicapped-infants   water-project-cost-sharing  \
# 0           1                     1                            2
# 1           1                     1                            2
# 2           0                     0                            2
# 3           0                     1                            2
# 4           0                     2                            2
#
#     adoption-of-the-budget-resolution   physician-fee-freeze  \
# 0                                   1                      2
# 1                                   1                      2
# 2                                   2                      0
# 3                                   2                      1
# 4                                   2                      1
#
#     el-salvador-aid   religious-groups-in-schools   anti-satellite-test-ban  \
# 0                 2                             2                         1
# 1                 2                             2                         1
# 2                 2                             2                         1
# 3                 0                             2                         1
# 4                 2                             2                         1
#
#     aid-to-nicaraguan-contras   mx-missile   immigration  \
# 0                           1            1             2
# 1                           1            1             1
# 2                           1            1             1
# 3                           1            1             1
# 4                           1            1             1
#
#     synfuels-corporation-cutback   education-spending  \
# 0                              0                    2
# 1                              1                    2
# 2                              2                    1
# 3                              2                    1
# 4                              2                    0
#
#     superfund-right-to-sue   crime   duty-free-exports  \
# 0                        2       2                   1
# 1                        2       2                   1
# 2                        2       2                   1
# 3                        2       1                   1
# 4                        2       2                   2
#
#     export-administration-act-south-africa
# 0                                        2
# 1                                        0
# 2                                        1
# 3                                        2
# 4                                        2

# %%
df.iloc[:,:].hist(figsize=(20,20))
plt.show()

# %% [markdown]
# # 3. Xây dựng và đánh giá mô hình

# %%
x = df.drop('Class Name', axis=1).values
y = df['Class Name'].values

print(x.shape)
print(y.shape)
# Out:
# (435, 16)
# (435,)

# %% [markdown]
# **Model**

# %%
def build_and_eval_model(clf):

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y, random_state=0)

    model = clf

    scoring = ['accuracy', 'precision', 'recall', 'f1']
    cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=0)
    scores = cross_validate(model, x_train, y_train, scoring=scoring, cv=cv, n_jobs=-1, error_score='raise')
    cv_scores = pd.DataFrame(scores).iloc[:, 2:]

    print('A. Cross Validation on Training Set')
    print(cv_scores.describe())

    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    final_scores = pd.DataFrame({'accuracy': [accuracy_score(y_test, y_pred)],
                                 'precision': [precision_score(y_test, y_pred)],
                                 'recall': [recall_score(y_test, y_pred)],
                                 'f1': [f1_score(y_test, y_pred)]})
    
    print('B. Final Validation on Test Set')
    print(final_scores.to_string(index=False))

    # Trực quan hóa kết quả đánh giá
    fig, axs = plt.subplots(1,2, figsize=(12,4))
    sns.boxplot(data=cv_scores, orient="h", palette="Set2", ax=axs[0])

    cm = confusion_matrix(y_test, y_pred)
    plt.imshow(cm, interpolation='none', cmap='Blues')
    for (i, j), z in np.ndenumerate(cm):
        plt.text(j, i, z, ha='center', va='center')
    plt.xlabel("Cluster label")
    plt.ylabel("True label")
    plt.show()

    cv_scores.to_csv('/content/gdrive/MyDrive/ML/giuaky/_cv_scores.csv'.format(clf.__class__.__name__), index=False)
    final_scores.to_csv('/content/gdrive/MyDrive/ML/giuaky/_final_scores.csv'.format(clf.__class__.__name__), index=False)

# %% [markdown]
# ## 3.1 K-Means

# %%
print('BUILD AND EVALUATE k-MEANS MODEL')
clf = KMeans(n_clusters=2, random_state=0)
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE k-MEANS MODEL
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.528834        0.423080     0.533333   0.471675
# std         0.367483        0.366686     0.458605   0.407246
# min         0.114754        0.000000     0.000000   0.000000
# 25%         0.156967        0.063508     0.085145   0.072727
# 50%         0.803279        0.689655     0.869565   0.769231
# 75%         0.866667        0.758621     0.956522   0.846154
# max         0.885246        0.793103     1.000000   0.867925
# B. Final Validation on Test Set
#  accuracy  precision   recall      f1
#   0.10687   0.041667 0.058824 0.04878
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %% [markdown]
# ## 3.2 kNN

# %%
#KNeighborsClassifier
grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

knn_class =  KNeighborsClassifier(n_neighbors = 10)

grid_knn_class = GridSearchCV(estimator=knn_class, param_grid= grid_params, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_knn_class.fit(x_train,y_train)
y_pred = grid_knn_class.predict(x_test)

print(grid_knn_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.9236641221374046
# 0.9177552007740687
# 0.9232843137254902
# 0.9202775073028238

# %%
print('BUILD AND EVALUATE k-NN MODEL')
clf = KNeighborsClassifier(metric='manhattan', n_neighbors= 11, weights= 'uniform')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE k-NN MODEL
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.914517        0.848521     0.948792   0.895255
# std         0.025620        0.042672     0.032969   0.030899
# min         0.852459        0.750000     0.913043   0.823529
# 25%         0.909016        0.818122     0.916667   0.888980
# 50%         0.918033        0.851852     0.956522   0.897959
# 75%         0.925683        0.880000     0.958333   0.909314
# max         0.950820        0.916667     1.000000   0.941176
# B. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.923664   0.886792 0.921569 0.903846

# %% [markdown]
# ## 3.3 DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(min_samples_leaf=10,min_samples_split=17,random_state=1)
build_and_eval_model(clf)
# Out:
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.957268        0.920772     0.974396   0.946129
# std         0.017277        0.032827     0.034826   0.021794
# min         0.934426        0.857143     0.875000   0.913043
# 25%         0.942213        0.902778     0.956522   0.929624
# 50%         0.966667        0.920000     1.000000   0.956522
# 75%         0.967213        0.955534     1.000000   0.959167
# max         0.983607        0.958333     1.000000   0.978723
# B. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.946565   0.923077 0.941176 0.932039

# %% [markdown]
# ## 3.4 SVM

# %%
# Using SVM
param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],'kernel': ['rbf','linear']}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

svm = svm.SVC(kernel='linear', random_state=0)

grid_svm_class = GridSearchCV(estimator=svm, param_grid= param_grid, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_svm_class.fit(x_train,y_train)
y_pred = grid_svm_class.predict(x_test)

print(grid_svm_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# 0.9465648854961832
# 0.9425511197663097
# 0.9455882352941176
# 0.944006838859376

# %%
print('BUILD AND EVALUATE SVM MODEL')
clf = SVC(kernel='linear', random_state=0, C=0.1, gamma=1)
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE SVM MODEL
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.955082        0.915552     0.974275   0.943466
# std         0.015710        0.029323     0.031484   0.019883
# min         0.934426        0.857143     0.913043   0.913043
# 25%         0.942213        0.900966     0.956522   0.929624
# 50%         0.950820        0.920000     1.000000   0.941176
# 75%         0.967213        0.923077     1.000000   0.958333
# max         0.983333        0.958333     1.000000   0.978723
# B. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.946565   0.923077 0.941176 0.932039

# %% [markdown]
# ## 3.5 RandomForestClassifier

# %%
#RandomForest
param_grid = {
    'n_estimators': [25, 50, 100, 150,300,500],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
    'criterion' :['gini', 'entropy']
}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

rf_class = RandomForestClassifier(random_state=0)

grid_rf_class = GridSearchCV(estimator=rf_class, param_grid= param_grid, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_rf_class.fit(x_train,y_train)
y_pred = grid_rf_class.predict(x_test)

print(grid_rf_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'criterion': 'entropy', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 6, 'n_estimators': 50}
# 0.9312977099236641
# 0.932605421686747
# 0.9224264705882352
# 0.9269380925822643

# %%
print('BUILD AND EVALUATE RANDOM FOREST MODEL')
clf = RandomForestClassifier(random_state=0, criterion='entropy', max_depth= 6, max_features= None, max_leaf_nodes= 6, n_estimators=50)
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE RANDOM FOREST MODEL
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.963825        0.929119     0.982729   0.954682
# std         0.020719        0.039882     0.021899   0.024930
# min         0.918033        0.827586     0.956522   0.905660
# 25%         0.958743        0.918333     0.956522   0.946346
# 50%         0.967213        0.956522     1.000000   0.958333
# 75%         0.983607        0.958333     1.000000   0.978723
# max         0.983607        0.960000     1.000000   0.979592
# B. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.931298     0.9375 0.882353 0.909091

# %% [markdown]
# ## 3.6 GaussianNB

# %%
clf = GaussianNB()
build_and_eval_model(clf)
# Out:
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.922204        0.871837     0.937440   0.902680
# std         0.021778        0.037819     0.039082   0.027209
# min         0.868852        0.777778     0.869565   0.840000
# 25%         0.917350        0.851852     0.913043   0.893617
# 50%         0.918033        0.875000     0.956522   0.901961
# 75%         0.934426        0.880000     0.958333   0.918333
# max         0.966667        0.956522     1.000000   0.956522
# B. Final Validation on Test Set
#  accuracy  precision   recall    f1
#  0.908397   0.933333 0.823529 0.875

# %% [markdown]
# ## 3.7 Neural Network

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

neuron_class = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(250, 100), random_state=1)

grid_mpl_class = GridSearchCV(estimator= neuron_class, param_grid=parameter_space, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_mpl_class.fit(x_train,y_train)
y_pred = grid_mpl_class.predict(x_test)

print(grid_mpl_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.9312977099236641
# 0.9370843989769821
# 0.9188725490196079
# 0.9263355201499531
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.

# %%
print('BUILD AND EVALUATE Neuron network MODEL')
clf =  MLPClassifier(activation='relu', alpha= 0.05, hidden_layer_sizes=(50, 100, 50), learning_rate='constant', solver= 'adam')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE Neuron network MODEL
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.947359        0.933165     0.931401   0.930964
# std         0.019890        0.033191     0.053696   0.027850
# min         0.916667        0.846154     0.826087   0.883721
# 25%         0.934426        0.918333     0.913043   0.913043
# 50%         0.950820        0.950000     0.956522   0.936170
# 75%         0.958743        0.956522     0.958333   0.947649
# max         0.983607        0.960000     1.000000   0.979592
# B. Final Validation on Test Set
#  accuracy  precision   recall  f1
#  0.923664   0.918367 0.882353 0.9

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

def buildModel(optimizer):
    # Initialising the ANN
    classifier = Sequential()
    
    # Adding the input layer and the first hidden layer
    classifier.add(Dense(units = 128, activation = 'relu'))
    
    # Adding the second hidden layer
    classifier.add(Dense(units = 64, activation = 'relu'))
    
    classifier.add(Dense(units = 32, activation = 'relu'))
    
    # Adding the output layer
    classifier.add(Dense(units = 1, activation = 'linear'))
    
    # Compiling the ANN
    classifier.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return classifier

# %%
parameters = {'batch_size': [16, 32, 64, 128],
              'epochs': [100, 150],
              'optimizer': ['adam', 'rmsprop']}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

keras_class = KerasClassifier(build_fn = buildModel)

grid_keras_class = GridSearchCV(estimator = keras_class, param_grid = parameters, scoring = 'neg_mean_absolute_error',  cv = 5)
grid_keras_class.fit(x_train, y_train, verbose = 0)
# Out:
# <ipython-input-32-649685ea70b5>:7: DeprecationWarning:
#
# KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4f205688b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4f2056b760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 1s 11ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# GridSearchCV(cv=5,
#              estimator=<keras.wrappers.scikit_learn.KerasClassifier object at 0x7f4f210581c0>,
#              param_grid={'batch_size': [16, 32, 64, 128], 'epochs': [100, 150],
#                          'optimizer': ['adam', 'rmsprop']},
#              scoring='neg_mean_absolute_error')

# %%
y_pred = grid_keras_class.predict(x_test)

print(grid_keras_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 5/5 [==============================] - 0s 3ms/step
# {'batch_size': 32, 'epochs': 150, 'optimizer': 'rmsprop'}
# 0.9389312977099237
# 0.9388999502239921
# 0.9322303921568628
# 0.9353086419753087

# %%
print('BUILD AND EVALUATE Neuron network MODEL')
clf = KerasClassifier(build_fn = buildModel,batch_size= 64, epochs= 100, optimizer= 'rmsprop')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE Neuron network MODEL
# <ipython-input-34-0046795932a5>:2: DeprecationWarning:
#
# KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# A. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.888415        0.765588     0.745652   0.754843
# std         0.143948        0.396838     0.388103   0.391295
# min         0.606557        0.000000     0.000000   0.000000
# 25%         0.926230        0.918333     0.850543   0.898382
# 50%         0.950820        0.956522     0.916667   0.938776
# 75%         0.966940        0.956522     0.956522   0.956522
# max         0.983607        1.000000     1.000000   0.979592
# Epoch 1/100
# 5/5 [==============================] - 1s 5ms/step - loss: 5.8933 - accuracy: 0.6151
# Epoch 2/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 3/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 4/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 6/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 8/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 9/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 10/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 11/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 12/100
# 5/5 [==============================] - 0s 6ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 13/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 14/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 15/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 16/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 17/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 18/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 19/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 20/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 21/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 22/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 23/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 24/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 25/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 26/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 27/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 28/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 30/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 31/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 32/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 33/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 34/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 35/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 36/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 37/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 38/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 40/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 41/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 42/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 43/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 44/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 45/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 46/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 47/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 48/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 49/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 50/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 51/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 52/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 53/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 54/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 55/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 57/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 58/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 59/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 60/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 61/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 62/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 63/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 64/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 65/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 66/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 67/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 68/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 69/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 70/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 71/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 72/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 73/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 74/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 76/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 77/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 78/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 79/100
# 5/5 [==============================] - 0s 7ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 80/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 82/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 83/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 84/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 85/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 86/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 87/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 88/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 89/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 90/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 91/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 92/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 93/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 94/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 95/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 96/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 97/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 98/100
# 5/5 [==============================] - 0s 5ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 99/100
# 5/5 [==============================] - 0s 3ms/step - loss: 5.9366 - accuracy: 0.6151
# Epoch 100/100
# 5/5 [==============================] - 0s 4ms/step - loss: 5.9366 - accuracy: 0.6151
# 5/5 [==============================] - 0s 3ms/step
# B. Final Validation on Test Set
#  accuracy  precision  recall  f1
#  0.610687        0.0     0.0 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# # 4. Kết luận

# %% [markdown]
# ## 4.1 Đánh giá giữa các mô hình

# %%
clf_names = ['KMeans','DecisionTree','GaussianNB','SVM','RandomForestClassifier', 'KNeighborsClassifier','Neuron network','Neuron network keras']
score_names = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1']

def build_plots(title):
    model_cv_scores = {clf_name: pd.read_csv('/content/gdrive/MyDrive/ML/giuaky/_cv_scores.csv'.format(clf_name)) for clf_name in clf_names}

    fig, axs = plt.subplots(2,2, figsize=(12,6))

    for score_name, ax in zip(score_names, axs.flat):
        score_data = pd.DataFrame({clf_name: model_cv_scores[clf_name][score_name] for clf_name in clf_names})
        sns.boxplot(data=score_data, orient="h", palette="Set2", ax=ax)
        ax.set_title(score_name)
    
    fig.suptitle(title)
    plt.tight_layout()

# %%
build_plots('ALL CLASSIFIERS')

# %%
clf_names.remove('KMeans')
build_plots('CLASSIFIERS WITHOUT k-MEANS')

# %% [markdown]
# ## 4.2 Quy trình xây dựng phân lớp

# %% [markdown]
# # Tài liệu tham khảo
