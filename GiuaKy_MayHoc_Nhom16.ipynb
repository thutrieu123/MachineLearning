# %% [markdown]
# <a href="https://colab.research.google.com/github/thutrieu123/MachineLearning/blob/main/GiuaKy_MayHoc_Nhom16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ĐỒ ÁN GIỮA KỲ MÔN MÁY HỌC**
#
# Triệu Anh Thư - 20130422,
# Đỗ Minh Phú - 20130365
#
# **DỰ ĐOÁN MÔ HÌNH BỎ PHIẾU BẦU CỬ CỦA NGƯỜI DÂN Ở QUỐC HỘI HOA KỲ**

# %% [markdown]
# # **Import Thư viện**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt
from plotly.offline import iplot

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedStratifiedKFold

from sklearn.metrics import  accuracy_score
from sklearn.metrics import  precision_score
from sklearn.metrics import  recall_score
from sklearn.metrics import  f1_score

from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from keras.wrappers.scikit_learn import KerasClassifier

from keras.layers import Dense
from keras.models import Sequential

# %% [markdown]
# # **1. Giới thiệu**

# %% [markdown]
# ## **1.1 Mục tiêu**

# %% [markdown]
# Mục tiêu là xây dựng được các mô hình dựa trên các thuật toán máy học được giảng dạy, có độ chính xác cao nhằm giải quyết bài toán dự đoán quyết định bỏ phiếu bầu cử của người dân ở Hòa Kỳ.

# %% [markdown]
# ## **1.2 Giới hạn**

# %% [markdown]
# *   Dữ liệu (dataset) được lấy từ Kaggle (1984).
# *   Thuật toán Máy Học được sử dụng để xây dựng các mô hình gồm có:
#
# 1. Logistic Regression
# 2. K- Nearest Neighbors
# 3. DecisionTree
# 4. SVM
# 5. RandomForest
# 6. GaussianNB
# 7. Neural Network (MLPClassifier, KerasClassifier)
#
# Có thể sử dụng thêm một số thuật toán khác để đối sánh.

# %% [markdown]
# # **2. Chuẩn bị dữ liệu**

# %% [markdown]
# ## **2.1 Thu thập dữ liệu**

# %% [markdown]
# Dữ liệu (Dataset) được lấy từ Kaggle (1984)
# https://www.kaggle.com/datasets/devvret/congressional-voting-records
#
# UCI.edu
# https://archive.ics.uci.edu/ml/datasets/congressional+voting+records
#
# Data.world
# https://data.world/uci/congressional-voting-records

# %% [markdown]
# ## **2.2 Thăm dò dữ liệu**

# %%
# import library from google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/NLU/MayHoc/Document/GiuaKi'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/NLU/MayHoc/Document/GiuaKi

# %%
# Đọc dữ liệu
df = pd.read_csv('house-votes-84.csv');

# %%
df
# Out:
#      Class Name  handicapped-infants  water-project-cost-sharing  \
# 0    republican                    n                           y
# 1    republican                    n                           y
# 2      democrat                    ?                           y
# 3      democrat                    n                           y
# 4      democrat                    y                           y
# ..          ...                  ...                         ...
# 430  republican                    n                           n
# 431    democrat                    n                           n
# 432  republican                    n                           ?
# 433  republican                    n                           n
# 434  republican                    n                           y
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                    n                     y                y
# 1                                    n                     y                y
# 2                                    y                     ?                y
# 3                                    y                     n                ?
# 4                                    y                     n                y
# ..                                 ...                   ...              ...
# 430                                  y                     y                y
# 431                                  y                     n                n
# 432                                  n                     y                y
# 433                                  n                     y                y
# 434                                  n                     y                y
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 0                              y                        n
# 1                              y                        n
# 2                              y                        n
# 3                              y                        n
# 4                              y                        n
# ..                           ...                      ...
# 430                            y                        n
# 431                            n                        y
# 432                            y                        n
# 433                            y                        ?
# 434                            y                        n
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                            n           n            y
# 1                            n           n            n
# 2                            n           n            n
# 3                            n           n            n
# 4                            n           n            n
# ..                         ...         ...          ...
# 430                          n           y            y
# 431                          y           y            y
# 432                          n           n            n
# 433                          ?           ?            ?
# 434                          n           n            y
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                               ?                   y                       y
# 1                               n                   y                       y
# 2                               y                   n                       y
# 3                               y                   n                       y
# 4                               y                   ?                       y
# ..                            ...                 ...                     ...
# 430                             n                   y                       y
# 431                             n                   n                       n
# 432                             y                   y                       y
# 433                             n                   y                       y
# 434                             n                   y                       y
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 0        y                  n                                       y
# 1        y                  n                                       ?
# 2        y                  n                                       n
# 3        n                  n                                       y
# 4        y                  y                                       y
# ..     ...                ...                                     ...
# 430      y                  n                                       y
# 431      n                  n                                       y
# 432      y                  n                                       y
# 433      y                  n                                       y
# 434      y                  ?                                       n
#
# [435 rows x 17 columns]

# %%
df.head(10)
# Out:
#    Class Name  handicapped-infants  water-project-cost-sharing  \
# 0  republican                    n                           y
# 1  republican                    n                           y
# 2    democrat                    ?                           y
# 3    democrat                    n                           y
# 4    democrat                    y                           y
# 5    democrat                    n                           y
# 6    democrat                    n                           y
# 7  republican                    n                           y
# 8  republican                    n                           y
# 9    democrat                    y                           y
#
#    adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                  n                     y                y
# 1                                  n                     y                y
# 2                                  y                     ?                y
# 3                                  y                     n                ?
# 4                                  y                     n                y
# 5                                  y                     n                y
# 6                                  n                     y                y
# 7                                  n                     y                y
# 8                                  n                     y                y
# 9                                  y                     n                n
#
#    religious-groups-in-schools  anti-satellite-test-ban  \
# 0                            y                        n
# 1                            y                        n
# 2                            y                        n
# 3                            y                        n
# 4                            y                        n
# 5                            y                        n
# 6                            y                        n
# 7                            y                        n
# 8                            y                        n
# 9                            n                        y
#
#    aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                          n           n            y
# 1                          n           n            n
# 2                          n           n            n
# 3                          n           n            n
# 4                          n           n            n
# 5                          n           n            n
# 6                          n           n            n
# 7                          n           n            n
# 8                          n           n            n
# 9                          y           y            n
#
#    synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                             ?                   y                       y
# 1                             n                   y                       y
# 2                             y                   n                       y
# 3                             y                   n                       y
# 4                             y                   ?                       y
# 5                             n                   n                       y
# 6                             n                   n                       ?
# 7                             n                   n                       y
# 8                             n                   y                       y
# 9                             n                   n                       n
#
#    crime  duty-free-exports  export-administration-act-south-africa
# 0      y                  n                                       y
# 1      y                  n                                       ?
# 2      y                  n                                       n
# 3      n                  n                                       y
# 4      y                  y                                       y
# 5      y                  y                                       y
# 6      y                  y                                       y
# 7      y                  ?                                       y
# 8      y                  n                                       y
# 9      n                  ?                                       ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Class Name                               435 non-null    object
#  1    handicapped-infants                     435 non-null    object
#  2    water-project-cost-sharing              435 non-null    object
#  3    adoption-of-the-budget-resolution       435 non-null    object
#  4    physician-fee-freeze                    435 non-null    object
#  5    el-salvador-aid                         435 non-null    object
#  6    religious-groups-in-schools             435 non-null    object
#  7    anti-satellite-test-ban                 435 non-null    object
#  8    aid-to-nicaraguan-contras               435 non-null    object
#  9    mx-missile                              435 non-null    object
#  10   immigration                             435 non-null    object
#  11   synfuels-corporation-cutback            435 non-null    object
#  12   education-spending                      435 non-null    object
#  13   superfund-right-to-sue                  435 non-null    object
#  14   crime                                   435 non-null    object
#  15   duty-free-exports                       435 non-null    object
#  16   export-administration-act-south-africa  435 non-null    object
# dtypes: object(17)
# memory usage: 57.9+ KB

# %%
# Đếm mẫu dữ liệu của 1 thuộc tính
df['Class Name'].value_counts()
# Out:
# democrat      267
# republican    168
# Name: Class Name, dtype: int64

# %%
df[' handicapped-infants'].value_counts()
# Out:
# n    236
# y    187
# ?     12
# Name:  handicapped-infants, dtype: int64

# %%
class Info:
    def __init__(self,dataframe):
        self.dataframe = dataframe.drop(['Class Name'],axis=1)
        self.columns = list(self.dataframe.columns)
        self.df = pd.DataFrame()
        self.listY = []
        self.listN = []
        self.listQ = []
        self.main()
        
    def countY(self,x='y'):
        for col in self.columns:
            self.listY.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listY
        
    def countN(self,x='n'):
        for col in self.columns:
            self.listN.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listN
        
    def countQ(self,x='?'):
        for col in self.columns:
            self.listQ.append((self.dataframe[col] == x).sum())
        self.df[x] = self.listQ

    
    def missing_zero_values_table(self):
        mis_val = self.dataframe.isnull().sum()
        mis_val_percent = round(self.dataframe.isnull().mean().mul(100),2)
        mz_table = pd.concat([mis_val,mis_val_percent],axis=1)
        mz_table = mz_table.rename(columns = {self.dataframe.index.name:'col_name',0:'Missing Values',1:'% of Total Values'})
        mz_table['Data_type'] = self.dataframe.dtypes
        print("Your selected dataframe has ** "+str(df.shape[1])+" ** columns and ** "+str(df.shape[0])+" ** Rows.\n"
                 "There are ** "+str(mz_table[mz_table.iloc[:,1] != 0].shape[0])+
                  " ** columns that have missing values. \n")
        self.df = pd.concat([self.df,mz_table],axis=1)
        
    def main(self):
        self.df['col'] = self.columns
        self.countN()
        self.countY()
        self.countQ()
        self.df.set_index('col',inplace=True)
        self.missing_zero_values_table()
        print('Sum No : ',sum(self.listN),
              ', Sum Yes : ',sum(self.listY),
              ', Sum ? : ',sum(self.listQ),
             ', Total : ',sum(self.listN)+sum(self.listY)+sum(self.listQ))

# %%
a = Info(df)
a.df.style.background_gradient(cmap='Reds')
# Out:
# Your selected dataframe has ** 17 ** columns and ** 435 ** Rows.
# There are ** 0 ** columns that have missing values.
#
# Sum No :  3147 , Sum Yes :  3421 , Sum ? :  392 , Total :  6960
# <style type="text/css">
# #T_0b727_row0_col0 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_0b727_row0_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_0b727_row0_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_0b727_row0_col3, #T_0b727_row0_col4, #T_0b727_row1_col3, #T_0b727_row1_col4, #T_0b727_row2_col3, #T_0b727_row2_col4, #T_0b727_row3_col3, #T_0b727_row3_col4, #T_0b727_row4_col3, #T_0b727_row4_col4, #T_0b727_row5_col3, #T_0b727_row5_col4, #T_0b727_row6_col3, #T_0b727_row6_col4, #T_0b727_row7_col3, #T_0b727_row7_col4, #T_0b727_row8_col3, #T_0b727_row8_col4, #T_0b727_row9_col2, #T_0b727_row9_col3, #T_0b727_row9_col4, #T_0b727_row10_col1, #T_0b727_row10_col3, #T_0b727_row10_col4, #T_0b727_row11_col3, #T_0b727_row11_col4, #T_0b727_row12_col3, #T_0b727_row12_col4, #T_0b727_row13_col3, #T_0b727_row13_col4, #T_0b727_row14_col3, #T_0b727_row14_col4, #T_0b727_row15_col0, #T_0b727_row15_col3, #T_0b727_row15_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_0b727_row1_col0 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_0b727_row1_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_0b727_row1_col2 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_0b727_row2_col0, #T_0b727_row9_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_0b727_row2_col1, #T_0b727_row11_col0, #T_0b727_row14_col0 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_0b727_row2_col2, #T_0b727_row3_col2, #T_0b727_row5_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_0b727_row3_col0 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_0b727_row3_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_0b727_row4_col0 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_0b727_row4_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_0b727_row4_col2, #T_0b727_row7_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_0b727_row5_col0 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_0b727_row5_col1, #T_0b727_row10_col0, #T_0b727_row15_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0b727_row6_col0 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_0b727_row6_col1 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_0b727_row6_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_0b727_row7_col0 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_0b727_row7_col1 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_0b727_row8_col0 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_0b727_row8_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_0b727_row8_col2 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_0b727_row9_col0 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_0b727_row10_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_0b727_row11_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_0b727_row11_col2 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_0b727_row12_col0 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_0b727_row12_col1 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_0b727_row12_col2 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_0b727_row13_col0 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_0b727_row13_col1 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_0b727_row13_col2 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_0b727_row14_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_0b727_row14_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_0b727_row15_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b727" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b727_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_0b727_level0_col1" class="col_heading level0 col1" >y</th>
#       <th id="T_0b727_level0_col2" class="col_heading level0 col2" >?</th>
#       <th id="T_0b727_level0_col3" class="col_heading level0 col3" >Missing Values</th>
#       <th id="T_0b727_level0_col4" class="col_heading level0 col4" >% of Total Values</th>
#       <th id="T_0b727_level0_col5" class="col_heading level0 col5" >Data_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b727_level0_row0" class="row_heading level0 row0" > handicapped-infants</th>
#       <td id="T_0b727_row0_col0" class="data row0 col0" >236</td>
#       <td id="T_0b727_row0_col1" class="data row0 col1" >187</td>
#       <td id="T_0b727_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_0b727_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0b727_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_0b727_row0_col5" class="data row0 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row1" class="row_heading level0 row1" > water-project-cost-sharing</th>
#       <td id="T_0b727_row1_col0" class="data row1 col0" >192</td>
#       <td id="T_0b727_row1_col1" class="data row1 col1" >195</td>
#       <td id="T_0b727_row1_col2" class="data row1 col2" >48</td>
#       <td id="T_0b727_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_0b727_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_0b727_row1_col5" class="data row1 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row2" class="row_heading level0 row2" > adoption-of-the-budget-resolution</th>
#       <td id="T_0b727_row2_col0" class="data row2 col0" >171</td>
#       <td id="T_0b727_row2_col1" class="data row2 col1" >253</td>
#       <td id="T_0b727_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_0b727_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_0b727_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_0b727_row2_col5" class="data row2 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row3" class="row_heading level0 row3" > physician-fee-freeze</th>
#       <td id="T_0b727_row3_col0" class="data row3 col0" >247</td>
#       <td id="T_0b727_row3_col1" class="data row3 col1" >177</td>
#       <td id="T_0b727_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_0b727_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_0b727_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_0b727_row3_col5" class="data row3 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row4" class="row_heading level0 row4" > el-salvador-aid</th>
#       <td id="T_0b727_row4_col0" class="data row4 col0" >208</td>
#       <td id="T_0b727_row4_col1" class="data row4 col1" >212</td>
#       <td id="T_0b727_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_0b727_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_0b727_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0b727_row4_col5" class="data row4 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row5" class="row_heading level0 row5" > religious-groups-in-schools</th>
#       <td id="T_0b727_row5_col0" class="data row5 col0" >152</td>
#       <td id="T_0b727_row5_col1" class="data row5 col1" >272</td>
#       <td id="T_0b727_row5_col2" class="data row5 col2" >11</td>
#       <td id="T_0b727_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_0b727_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_0b727_row5_col5" class="data row5 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row6" class="row_heading level0 row6" > anti-satellite-test-ban</th>
#       <td id="T_0b727_row6_col0" class="data row6 col0" >182</td>
#       <td id="T_0b727_row6_col1" class="data row6 col1" >239</td>
#       <td id="T_0b727_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_0b727_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_0b727_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_0b727_row6_col5" class="data row6 col5" >object</td>
#     </tr>
#     <tr>
#       <th id="T_0b727_level0_row7" class="row_heading level0 row7" > aid-to-nicaraguan-contras</th>
#       <td id="T_0b727_row7_col0" class="data row7 col0" >178</td>
#       <td id="

# %%
px.bar(a.df,x=a.df.index, y=['n','y','?'], title="Votes related to laws")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9d21bd71-dfb8-4895-b7d8-f88dfbdc229b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d21bd71-dfb8-4895-b7d8-f88dfbdc229b")) {                    Plotly.newPlot(                        "9d21bd71-dfb8-4895-b7d8-f88dfbdc229b",                        [{"alignmentgroup":"True","hovertemplate":"variable=n<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"n","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"n","offsetgroup":"n","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[236,192,171,247,208,152,182,178,206,212,264,233,201,170,233,62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=y<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"y","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"y","offsetgroup":"y","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[187,195,253,177,212,272,239,242,207,216,150,171,209,248,174,269],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=?<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"?","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"?","offsetgroup":"?","orientation":"v","showlegend":true,"textposition":"auto","x":[" handicapped-infants"," water-project-cost-sharing"," adoption-of-the-budget-resolution"," physician-fee-freeze"," el-salvador-aid"," religious-groups-in-schools"," anti-satellite-test-ban"," aid-to-nicaraguan-contras"," mx-missile"," immigration"," synfuels-corporation-cutback"," education-spending"," superfund-right-to-sue"," crime"," duty-free-exports"," export-administration-act-south-africa"],"xaxis":"x","y":[12,48,11,11,15,11,14,15,22,7,21,31,25,17,28,104],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...

# %%
# Số lượng phiếu vote cao nhất
maximumVote = {}
for col in df.columns.tolist()[1:]:
    maximumVote[col] = df.groupby([col,'Class Name']).count().idxmax()[0]

# %%
maximumVote = pd.DataFrame(list(maximumVote.items()),columns = ['columns','TupleVotes'])
maximumVote
# Out:
#                                     columns       TupleVotes
# 0                       handicapped-infants    (y, democrat)
# 1                water-project-cost-sharing    (y, democrat)
# 2         adoption-of-the-budget-resolution    (y, democrat)
# 3                      physician-fee-freeze    (n, democrat)
# 4                           el-salvador-aid    (n, democrat)
# 5               religious-groups-in-schools  (y, republican)
# 6                   anti-satellite-test-ban    (y, democrat)
# 7                 aid-to-nicaraguan-contras    (y, democrat)
# 8                                mx-missile    (y, democrat)
# 9                               immigration    (n, democrat)
# 10             synfuels-corporation-cutback  (n, republican)
# 11                       education-spending    (n, democrat)
# 12                   superfund-right-to-sue    (n, democrat)
# 13                                    crime    (n, democrat)
# 14                        duty-free-exports    (y, democrat)
# 15   export-administration-act-south-africa    (y, democrat)

# %%
# Bỏ phiếu lại
resVoting = {}
for col in df.columns.tolist()[1:]:
    resVoting[col] = df[col].value_counts().idxmax()

# %%
resVoting = pd.DataFrame(list(resVoting.items()),columns = ['columns','FinalRes'])
resVoting
# Out:
#                                     columns FinalRes
# 0                       handicapped-infants        n
# 1                water-project-cost-sharing        y
# 2         adoption-of-the-budget-resolution        y
# 3                      physician-fee-freeze        n
# 4                           el-salvador-aid        y
# 5               religious-groups-in-schools        y
# 6                   anti-satellite-test-ban        y
# 7                 aid-to-nicaraguan-contras        y
# 8                                mx-missile        y
# 9                               immigration        y
# 10             synfuels-corporation-cutback        n
# 11                       education-spending        n
# 12                   superfund-right-to-sue        y
# 13                                    crime        y
# 14                        duty-free-exports        n
# 15   export-administration-act-south-africa        y

# %%
labels = resVoting.FinalRes.value_counts().index
x = resVoting.FinalRes.value_counts()
ResultVoting = go.Pie(labels=labels,values=x,hoverinfo='label+percent',
                      textinfo='value',title='Voting results')
iplot([ResultVoting])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3c23b1e4-48d4-4a20-9bf1-c8f8ef450b14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c23b1e4-48d4-4a20-9bf1-c8f8ef450b14")) {                    Plotly.newPlot(                        "3c23b1e4-48d4-4a20-9bf1-c8f8ef450b14",                        [{"hoverinfo":"label+percent","labels":["y","n"],"textinfo":"value","title":{"text":"Voting results"},"values":[11,5],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scatter ...

# %% [markdown]
# ## **2.3 Sơ chế dữ liệu**

# %%
# Chuyển đổi dữ liệu
le = LabelEncoder() 
df['Class Name']= le.fit_transform(df['Class Name']) 
df[' handicapped-infants']= le.fit_transform(df[' handicapped-infants']) 
df[' water-project-cost-sharing']= le.fit_transform(df[' water-project-cost-sharing']) 
df[' adoption-of-the-budget-resolution']= le.fit_transform(df[' adoption-of-the-budget-resolution']) 
df[' physician-fee-freeze']= le.fit_transform(df[' physician-fee-freeze']) 
df[' el-salvador-aid']= le.fit_transform(df[' el-salvador-aid']) 
df[' religious-groups-in-schools']= le.fit_transform(df[' religious-groups-in-schools']) 
df[' anti-satellite-test-ban']= le.fit_transform(df[' anti-satellite-test-ban']) 
df[' aid-to-nicaraguan-contras']= le.fit_transform(df[' aid-to-nicaraguan-contras']) 
df[' mx-missile']= le.fit_transform(df[' mx-missile']) 
df[' immigration']= le.fit_transform(df[' immigration']) 
df[' synfuels-corporation-cutback']= le.fit_transform(df[' synfuels-corporation-cutback']) 
df[' education-spending']= le.fit_transform(df[' education-spending']) 
df[' superfund-right-to-sue']= le.fit_transform(df[' superfund-right-to-sue']) 
df[' crime']= le.fit_transform(df[' crime']) 
df[' duty-free-exports']= le.fit_transform(df[' duty-free-exports']) 
df[' export-administration-act-south-africa']= le.fit_transform(df[' export-administration-act-south-africa']) 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Class Name                               435 non-null    int64
#  1    handicapped-infants                     435 non-null    int64
#  2    water-project-cost-sharing              435 non-null    int64
#  3    adoption-of-the-budget-resolution       435 non-null    int64
#  4    physician-fee-freeze                    435 non-null    int64
#  5    el-salvador-aid                         435 non-null    int64
#  6    religious-groups-in-schools             435 non-null    int64
#  7    anti-satellite-test-ban                 435 non-null    int64
#  8    aid-to-nicaraguan-contras               435 non-null    int64
#  9    mx-missile                              435 non-null    int64
#  10   immigration                             435 non-null    int64
#  11   synfuels-corporation-cutback            435 non-null    int64
#  12   education-spending                      435 non-null    int64
#  13   superfund-right-to-sue                  435 non-null    int64
#  14   crime                                   435 non-null    int64
#  15   duty-free-exports                       435 non-null    int64
#  16   export-administration-act-south-africa  435 non-null    int64
# dtypes: int64(17)
# memory usage: 57.9 KB

# %%
df.head(5)
# Out:
#    Class Name   handicapped-infants   water-project-cost-sharing  \
# 0           1                     1                            2
# 1           1                     1                            2
# 2           0                     0                            2
# 3           0                     1                            2
# 4           0                     2                            2
#
#     adoption-of-the-budget-resolution   physician-fee-freeze  \
# 0                                   1                      2
# 1                                   1                      2
# 2                                   2                      0
# 3                                   2                      1
# 4                                   2                      1
#
#     el-salvador-aid   religious-groups-in-schools   anti-satellite-test-ban  \
# 0                 2                             2                         1
# 1                 2                             2                         1
# 2                 2                             2                         1
# 3                 0                             2                         1
# 4                 2                             2                         1
#
#     aid-to-nicaraguan-contras   mx-missile   immigration  \
# 0                           1            1             2
# 1                           1            1             1
# 2                           1            1             1
# 3                           1            1             1
# 4                           1            1             1
#
#     synfuels-corporation-cutback   education-spending  \
# 0                              0                    2
# 1                              1                    2
# 2                              2                    1
# 3                              2                    1
# 4                              2                    0
#
#     superfund-right-to-sue   crime   duty-free-exports  \
# 0                        2       2                   1
# 1                        2       2                   1
# 2                        2       2                   1
# 3                        2       1                   1
# 4                        2       2                   2
#
#     export-administration-act-south-africa
# 0                                        2
# 1                                        0
# 2                                        1
# 3                                        2
# 4                                        2

# %%
df.iloc[:,:].hist(figsize=(20,20))

plt.show()

# %% [markdown]
# # **3. Xây dựng và đánh giá mô hình**

# %%
x = df.drop('Class Name', axis=1).values
y = df['Class Name'].values

print(x.shape)
print(y.shape)
# Out:
# (435, 16)
# (435,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.3, stratify= None, random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (304, 16)
# (131, 16)
# (304,)
# (131,)

# %% [markdown]
# **Model**

# %%
def build_and_eval_model(clf):

    # x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify= None, random_state=0)

    model = clf
    # Đánh giá mô hình bằng Kiểm chứng chéo trên Training Set
    scoring = ['accuracy', 'precision', 'recall', 'f1']

    cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=0)
    scores = cross_validate(model, x_train, y_train, scoring=scoring, cv=cv, n_jobs=-1, error_score='raise')
    cv_scores = pd.DataFrame(scores).iloc[:, 2:]

    print('I. Cross Validation on Training Set')
    print(cv_scores.describe())

    # Huấn luyện mô hình
    model.fit(x_train, y_train)

    # Dùng mô hình dự đoán trên Test Set
    y_pred = model.predict(x_test)

    # Đánh giá kết quả dự đoán của mô hình trên Test Set
    final_scores = pd.DataFrame({'accuracy': [accuracy_score(y_test, y_pred)],
                                 'precision': [precision_score(y_test, y_pred)],
                                 'recall': [recall_score(y_test, y_pred)],
                                 'f1': [f1_score(y_test, y_pred)]})
    
    print('II. Final Validation on Test Set')
    print(final_scores.to_string(index=False))

    # Trực quan hóa kết quả đánh giá
    fig, axs = plt.subplots(1,2, figsize=(12,4))
    sns.boxplot(data=cv_scores, orient="h", palette="Set2", ax=axs[0])

    cm = confusion_matrix(y_test, y_pred)
    plt.imshow(cm, interpolation='none', cmap='Blues')
    for (i, j), z in np.ndenumerate(cm):
        plt.text(j, i, z, ha='center', va='center')
    plt.xlabel("Cluster label")
    plt.ylabel("True label")
    plt.show()

    # Lưu kết quả đánh giá
    cv_scores.to_csv('/content/gdrive/MyDrive/NLU/MayHoc/Document/GiuaKi/{}_cv_scores.csv'.format(clf.__class__.__name__), index=False)
    final_scores.to_csv('/content/gdrive/MyDrive/NLU/MayHoc/Document/GiuaKi/{}_final_scores.csv'.format(clf.__class__.__name__), index=False)

# %% [markdown]
# ## **3.1 SVM**

# %%
# Using SVM
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf','linear']}

svm_class = SVC()

grid_svm_class = GridSearchCV(estimator=svm_class, param_grid= param_grid, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_svm_class.fit(x_train,y_train)
y_pred = grid_svm_class.predict(x_test)

print(grid_svm_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.9541984732824428
# 0.9486904761904762
# 0.9587390457643622
# 0.9527417027417027

# %%
print('BUILD AND EVALUATE SVM MODEL')
clf = SVC(C= 10, gamma= 0.01, kernel='rbf')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE SVM MODEL
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.951749        0.917694     0.962681   0.938720
# std         0.027441        0.053626     0.035893   0.034486
# min         0.916667        0.846154     0.913043   0.893617
# 25%         0.926230        0.882308     0.936594   0.905501
# 50%         0.950820        0.913043     0.956522   0.938776
# 75%         0.975273        0.957273     1.000000   0.968056
# max         1.000000        1.000000     1.000000   1.000000
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.954198   0.910714 0.980769 0.944444

# %% [markdown]
# ## **3.2 LogisticRegression**

# %%
print('BUILD AND EVALUATE LOGISTIC REGRESSION MODEL')
clf = LogisticRegression(max_iter=1000)
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE LOGISTIC REGRESSION MODEL
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.939690        0.919774     0.925604   0.920853
# std         0.020315        0.039249     0.058832   0.028416
# min         0.901639        0.851852     0.791667   0.863636
# 25%         0.925683        0.894545     0.913043   0.903330
# 50%         0.934426        0.916667     0.956522   0.920000
# 75%         0.950820        0.955534     0.956522   0.936170
# max         0.967213        0.958333     1.000000   0.958333
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.938931   0.907407 0.942308 0.924528

# %% [markdown]
# ## **3.3 DecisionTreeClassifier**

# %%
clf = DecisionTreeClassifier(min_samples_leaf= 10, min_samples_split= 17, random_state=1)
build_and_eval_model(clf)
# Out:
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.957250        0.928275     0.965459   0.945571
# std         0.027675        0.055324     0.033617   0.034768
# min         0.916667        0.846154     0.913043   0.893617
# 25%         0.934426        0.884615     0.956522   0.916522
# 50%         0.967213        0.920000     0.958333   0.958333
# 75%         0.983333        0.980000     1.000000   0.977778
# max         1.000000        1.000000     1.000000   1.000000
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.954198   0.910714 0.980769 0.944444

# %% [markdown]
# ## **3.4 GaussianNB**

# %%
clf = GaussianNB()
build_and_eval_model(clf)
# Out:
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.918871        0.882861     0.914130   0.896668
# std         0.042309        0.074174     0.055482   0.052937
# min         0.836066        0.785714     0.791667   0.791667
# 25%         0.885246        0.833333     0.869565   0.856904
# 50%         0.918033        0.851852     0.913043   0.897959
# 75%         0.950820        0.954545     0.956522   0.933333
# max         1.000000        1.000000     1.000000   1.000000
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.900763   0.830508 0.942308 0.882883

# %% [markdown]
# ## **3.5 RandomForestClassifier**

# %%
#RandomForest
param_grid = {
    'n_estimators': [25, 50, 100, 150,300,500],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
    'criterion' :['gini', 'entropy']
}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

rf_class = RandomForestClassifier(random_state=0)

grid_rf_class = GridSearchCV(estimator=rf_class, param_grid= param_grid, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_rf_class.fit(x_train,y_train)
y_pred = grid_rf_class.predict(x_test)

print(grid_rf_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'criterion': 'entropy', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 6, 'n_estimators': 50}
# 0.9312977099236641
# 0.932605421686747
# 0.9224264705882352
# 0.9269380925822643

# %%
print('BUILD AND EVALUATE RANDOM FOREST MODEL')
clf = RandomForestClassifier(random_state=0, criterion='entropy', max_depth= 6, max_features= None, max_leaf_nodes= 6, n_estimators=50)
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE RANDOM FOREST MODEL
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.956157        0.927905     0.962681   0.943974
# std         0.024636        0.050655     0.035893   0.030975
# min         0.916667        0.846154     0.913043   0.897959
# 25%         0.934426        0.898829     0.936594   0.914855
# 50%         0.950820        0.920000     0.956522   0.938776
# 75%         0.983333        0.958333     1.000000   0.977778
# max         0.983607        1.000000     1.000000   0.978723
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.961832   0.927273 0.980769 0.953271

# %% [markdown]
# ## **3.6 K-nn**

# %%
#KNeighborsClassifier
grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

knn_class =  KNeighborsClassifier(n_neighbors = 10)

grid_knn_class = GridSearchCV(estimator=knn_class, param_grid= grid_params, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_knn_class.fit(x_train,y_train)
y_pred = grid_knn_class.predict(x_test)

print(grid_knn_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# 0.9236641221374046
# 0.9177552007740687
# 0.9232843137254902
# 0.9202775073028238

# %%
print('BUILD AND EVALUATE k-NN MODEL')
clf = KNeighborsClassifier(metric='manhattan', n_neighbors= 11, weights= 'uniform')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE k-NN MODEL
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.914517        0.848521     0.948792   0.895255
# std         0.025620        0.042672     0.032969   0.030899
# min         0.852459        0.750000     0.913043   0.823529
# 25%         0.909016        0.818122     0.916667   0.888980
# 50%         0.918033        0.851852     0.956522   0.897959
# 75%         0.925683        0.880000     0.958333   0.909314
# max         0.950820        0.916667     1.000000   0.941176
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.923664   0.886792 0.921569 0.903846

# %% [markdown]
# ## **3.7 Neuron Network**

# %% [markdown]
# ### **3.7.1 MLPClassifier**

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

neuron_class = MLPClassifier(solver='lbfgs', hidden_layer_sizes=(250, 100), random_state=1)

grid_mpl_class = GridSearchCV(estimator= neuron_class, param_grid=parameter_space, scoring='accuracy', n_jobs=4, cv=10, refit=True, return_train_score=True)

grid_mpl_class.fit(x_train,y_train)
y_pred = grid_mpl_class.predict(x_test)

print(grid_mpl_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.9312977099236641
# 0.9370843989769821
# 0.9188725490196079
# 0.9263355201499531
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.

# %%
print('BUILD AND EVALUATE Neuron network MODEL')
clf =  MLPClassifier(activation='relu', alpha= 0.05, hidden_layer_sizes=(50, 100, 50), learning_rate='constant', solver= 'adam')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE Neuron network MODEL
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.936375        0.909863     0.928382   0.917199
# std         0.029186        0.048240     0.063748   0.038454
# min         0.883333        0.807692     0.791667   0.844444
# 25%         0.918033        0.884615     0.913043   0.886305
# 50%         0.950820        0.913043     0.913043   0.933333
# 75%         0.958743        0.954545     0.979167   0.947649
# max         0.967213        0.958333     1.000000   0.958333
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.969466   0.944444 0.980769 0.962264

# %% [markdown]
# ### **3.7.2 KerasClassifier**

# %%
def buildModel(optimizer):
    # Initialising the ANN
    classifier = Sequential()
    
    # Adding the input layer and the first hidden layer
    classifier.add(Dense(units = 128, activation = 'relu'))
    
    # Adding the second hidden layer
    classifier.add(Dense(units = 64, activation = 'relu'))
    classifier.add(Dense(units = 32, activation = 'relu'))
  
    # Adding the output layer
    classifier.add(Dense(units = 1, activation = 'linear'))
    
    # Compiling the ANN
    classifier.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return classifier

# %%
param_grid = {'batch_size': [16, 32, 64, 128],
              'epochs': [100, 150],
              'optimizer': ['adam', 'rmsprop']}

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.3, stratify= y, random_state=0)

keras_class = KerasClassifier(build_fn = buildModel)

grid_keras_class = GridSearchCV(estimator = keras_class, param_grid = param_grid, scoring = 'neg_mean_absolute_error',  cv = 5)
grid_keras_class.fit(x_train, y_train, verbose = 0)
y_pred = grid_keras_class.predict(x_test)

print(grid_keras_class.best_params_)
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# <ipython-input-88-4af62a60ab0f>:7: DeprecationWarning:
#
# KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 5/5 [==============================] - 0s 3ms/step
# {'batch_size': 32, 'epochs': 100, 'optimizer': 'adam'}
# 0.6106870229007634
# 0.3053435114503817
# 0.5
# 0.3791469194312796
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
print('BUILD AND EVALUATE Neuron network MODEL')
clf = KerasClassifier(build_fn = buildModel, batch_size= 64, epochs= 150, optimizer= 'rmsprop')
build_and_eval_model(clf)
# Out:
# BUILD AND EVALUATE Neuron network MODEL
# <ipython-input-89-9960d255403b>:2: DeprecationWarning:
#
# KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# I. Cross Validation on Training Set
#        test_accuracy  test_precision  test_recall    test_f1
# count      15.000000       15.000000    15.000000  15.000000
# mean        0.829727        0.612248     0.614976   0.612101
# std         0.159088        0.449362     0.453658   0.448847
# min         0.606557        0.000000     0.000000   0.000000
# 25%         0.619809        0.000000     0.000000   0.000000
# 50%         0.934426        0.888889     0.913043   0.913043
# 75%         0.942623        0.918333     0.957428   0.929388
# max         0.967213        1.000000     1.000000   0.956522
# Epoch 1/150
# 5/5 [==============================] - 1s 4ms/step - loss: 0.8502 - accuracy: 0.6349
# Epoch 2/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3727 - accuracy: 0.8520
# Epoch 3/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2396 - accuracy: 0.9112
# Epoch 4/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2615 - accuracy: 0.9046
# Epoch 5/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8586
# Epoch 6/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.9474
# Epoch 7/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1407 - accuracy: 0.9441
# Epoch 8/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1263 - accuracy: 0.9507
# Epoch 9/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.9441
# Epoch 10/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1727 - accuracy: 0.9408
# Epoch 11/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1829 - accuracy: 0.9211
# Epoch 12/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9539
# Epoch 13/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9572
# Epoch 14/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1297 - accuracy: 0.9704
# Epoch 15/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9704
# Epoch 16/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1660 - accuracy: 0.9507
# Epoch 17/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1848 - accuracy: 0.9375
# Epoch 18/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1925 - accuracy: 0.9145
# Epoch 19/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9737
# Epoch 20/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 0.9836
# Epoch 21/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9704
# Epoch 22/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9737
# Epoch 23/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9868
# Epoch 24/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9836
# Epoch 25/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0999 - accuracy: 0.9836
# Epoch 26/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.9638
# Epoch 27/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9671
# Epoch 28/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 0.9836
# Epoch 29/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9836
# Epoch 30/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9737
# Epoch 31/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9901
# Epoch 32/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0357 - accuracy: 0.9836
# Epoch 33/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1992 - accuracy: 0.9539
# Epoch 34/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9934
# Epoch 35/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9934
# Epoch 36/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9572
# Epoch 37/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9934
# Epoch 38/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9901
# Epoch 39/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9868
# Epoch 40/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0306 - accuracy: 0.9901
# Epoch 41/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 0.9704
# Epoch 42/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9934
# Epoch 43/150
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9901
# Epoch 44/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9803
# Epoch 45/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9836
# Epoch 46/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9934
# Epoch 47/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9934
# Epoch 48/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9967
# Epoch 49/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9901
# Epoch 50/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9934
# Epoch 51/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9967
# Epoch 52/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9901
# Epoch 53/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.9276
# Epoch 54/150
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 55/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9967
# Epoch 56/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9967
# Epoch 57/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9967
# Epoch 58/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9967
# Epoch 59/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9967
# Epoch 60/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9967
# Epoch 61/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9967
# Epoch 62/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.9901
# Epoch 63/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9967
# Epoch 64/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9967
# Epoch 65/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 66/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0693 - accuracy: 0.9605
# Epoch 67/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9967
# Epoch 68/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9967
# Epoch 69/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9967
# Epoch 70/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9967
# Epoch 71/150
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9671
# Epoch 72/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9967
# Epoch 73/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9967
# Epoch 74/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 0.9967
# Epoch 75/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9967
# Epoch 76/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9967
# Epoch 77/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9967
# Epoch 78/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9901
# Epoch 79/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9967
# Epoch 80/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9967
# Epoch 81/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9967
# Epoch 82/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9967
# Epoch 83/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9967
# Epoch 84/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9934
# Epoch 85/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 0.9967
# Epoch 86/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9967
# Epoch 87/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 88/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9967
# Epoch 89/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9737
# Epoch 90/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9967
# Epoch 91/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 92/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9967
# Epoch 93/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 94/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9934
# Epoch 95/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9836
# Epoch 96/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 97/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 98/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9967
# Epoch 99/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9967
# Epoch 100/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 101/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0337 - accuracy: 0.9836
# Epoch 102/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0601 - accuracy: 0.9901
# Epoch 103/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9967
# Epoch 104/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 105/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 106/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9967
# Epoch 107/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9901
# Epoch 108/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9868
# Epoch 109/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9967
# Epoch 110/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 111/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 112/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9967
# Epoch 113/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9967
# Epoch 114/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 115/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9934
# Epoch 116/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9967
# Epoch 117/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 118/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 0.9967
# Epoch 119/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 120/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 121/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9836
# Epoch 122/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.9836
# Epoch 123/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9967
# Epoch 124/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 125/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 126/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9967
# Epoch 127/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1660 - accuracy: 0.9671
# Epoch 128/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9967
# Epoch 129/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 130/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 131/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 132/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 133/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 134/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 135/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 136/150
# 5/5 [==============================] - 0s 4ms/step - loss: 8.9316e-04 - accuracy: 1.0000
# Epoch 137/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 138/150
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0890 - accuracy: 0.9704
# Epoch 139/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 140/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 141/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 142/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 143/150
# 5/5 [==============================] - 0s 4ms/step - loss: 9.2250e-04 - accuracy: 1.0000
# Epoch 144/150
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1905e-04 - accuracy: 1.0000
# Epoch 145/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9967
# Epoch 146/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 147/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 148/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 149/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 150/150
# 5/5 [==============================] - 0s 5ms/step - loss: 8.1305e-04 - accuracy: 1.0000
# 5/5 [==============================] - 0s 3ms/step
# II. Final Validation on Test Set
#  accuracy  precision   recall       f1
#  0.961832   0.979167 0.921569 0.949495

# %% [markdown]
# # **4. Kết Luận**

# %% [markdown]
# ## **4.1 Đánh giá giữa các mô hình**

# %%
clf_names = ['SVC','LogisticRegression','DecisionTreeClassifier','GaussianNB','RandomForestClassifier','KNeighborsClassifier','MLPClassifier','KerasClassifier']
score_names = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1']

# %%
def build_plots(title):
    model_cv_scores = {clf_name: pd.read_csv('/content/gdrive/MyDrive/NLU/MayHoc/Document/GiuaKi/{}_cv_scores.csv'.format(clf_name)) for clf_name in clf_names}

    fig, axs = plt.subplots(2,2, figsize=(12,6))

    for score_name, ax in zip(score_names, axs.flat):
        score_data = pd.DataFrame({clf_name: model_cv_scores[clf_name][score_name] for clf_name in clf_names})
        sns.boxplot(data = score_data, orient="h", palette="Set2", ax=ax)
        ax.set_title(score_name)
    
    fig.suptitle(title)
    plt.tight_layout()

# %%
build_plots('ALL CLASSIFIERS')

# %% [markdown]
# ![263156772_447561793539954_6371174665761422011_n.png](data:image/png;base64,...)
#
# Precision & Recall & Accuracy

# %% [markdown]
# Nhìn vào 4 biểu đồ, ta có một số kết luận:
#
#
# *   **Accuracy** (Độ chính xác tổng quát), **Precision** (Độ chính xác),**Recall** (Độ nhạy) và **F1** tương đối cao ở tất cả mô hình.
# *   Đối với mô hình của thuật toán **RandomForestClassifier** chỉ số tương đối cao với *Accuracy = 0.956, Precision = 0.927, Recall = 0.962*.
# *   Đối với mô hình của thuật toán **NeuralNetwork** là **MLPClassifier** và **KerasClassifier** chỉ số *Accuracy = 0.952, Precision = 0.942, Recall = 0.937* có precision cao nhưng accuracy và recall thấp hơn nên không khả quan.
# *   Tuy nhiên, các chỉ số của thuật toán **DecisionTreeClassifier** ở cả 4 biểu đồ nhìn chung là cao nhất trong bài toán này.
#
#
# => Như vậy, mô hình của thuật toán **DecisionTreeClassifier** có thể đáp ứng được nhu cầu bài toán dự đoán này với *Accuracy = 0.957, Precision = 0.928, Recall = 0.965*.

# %% [markdown]
# # **5. Tài liệu tham khảo**

# %% [markdown]
# *   Aristides Gionis and Heikki Mannila and Panayiotis Tsaparas. Clustering Aggregation. ICDE. 2005. [View Context].
# *   Julie Greensmith. New Frontiers For An Artificial Immune System. Digital Media Systems Laboratory HP Laboratories Bristol. 2003. [View Context].
# *   Daniel J. Lizotte and Omid Madani and Russell Greiner. Budgeted Learning of Naive-Bayes Classifiers. UAI. 2003. [View Context]
# *   Federico Divina and Elena Marchiori. Evolutionary Concept Learning. GECCO. 2002. [View Context].
